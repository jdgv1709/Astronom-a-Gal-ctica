# %% [markdown]
# # Practica 11
# # Juan David Galan Vargas - 202111470

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\juang\Documents\Tareas JD\Universidad\Materias\7 Semestre\Astronomia Galactica\Practica 11\Variables Magallanes.csv")
df.shape
# Out:
# (1087, 4)

# %%
df=df.sort_values(by="P")

# %%
df.sort_values(by="magMin")
# Out:
#      magMax           P  magMin VarType
# 330   17.60    1.552220    0.70    DCEP
# 327   18.10    1.736110    0.80    DCEP
# 267   17.90    2.036910    1.10    DCEP
# 169   11.53  127.610000   12.44    DCEP
# 907   11.79   73.384900   12.55    DCEP
# ..      ...         ...     ...     ...
# 256   16.80    2.267340   18.60    DCEP
# 829   17.70    1.564169   18.60    DCEP
# 44    17.60    1.335427   18.60    DCEP
# 349   17.60    1.297493   18.60    DCEP
# 318   17.70    1.134080   18.70    DCEP
#
# [1087 rows x 4 columns]

# %%
from sklearn.linear_model import LinearRegression
from scipy.stats import linregress

# %%
plt.scatter(df["P"],df["magMax"], marker=".")
#plt.scatter(df["P"],df["magMin"])
plt.xscale('log')
plt.gca().invert_yaxis()
plt.title("Magnitudes Superiores de Estrellas Cefeidas de SMC")
slope, intercept, r_value, p_value, std_err = linregress(np.log(df["P"]),df["magMax"])
plt.plot(df["P"], slope*np.log(df["P"]) + intercept, color='red', label="P* "+str(slope)+" + "+str(intercept))
plt.legend()
plt.xlabel("Periodo [Dias]")
plt.ylabel("Magnitud")
# Out:
# Text(0, 0.5, 'Magnitud')

# %%
#plt.scatter(df["P"],df["magMax"])
plt.scatter(df["P"],df["magMin"], marker=".")
plt.xscale('log')
plt.gca().invert_yaxis()
slope, intercept, r_value, p_value, std_err = linregress(np.log(df["P"]),df["magMin"])
plt.plot(df["P"], slope*np.log(df["P"]) + intercept, color='red', label="P* "+str(slope)+" + "+str(intercept))
plt.legend()
plt.title("Magnitudes Inferiores de Estrellas Cefeidas de SMC")
plt.xlabel("Periodo [Dias]")
plt.ylabel("Magnitud")
# Out:
# Text(0, 0.5, 'Magnitud')

# %%
plt.scatter(df["P"],df["magMax"], label="Maximos", marker=".")
#plt.scatter(df["P"],df["magMin"])
slope, intercept, r_value, p_value, std_err = linregress(np.log(df["P"]),df["magMax"])
plt.plot(df["P"], slope*np.log(df["P"]) + intercept, color='red')


#plt.scatter(df["P"],df["magMax"])
plt.scatter(df["P"],df["magMin"], label="Minimos", marker="x")
plt.xscale('log')
plt.gca().invert_yaxis()
slope, intercept, r_value, p_value, std_err = linregress(np.log(df["P"]),df["magMin"])
plt.plot(df["P"], slope*np.log(df["P"]) + intercept, color='red')
plt.legend()
plt.title("Magnitudes  Superiores e Inferiores de Estrellas Cefeidas de SMC")
plt.xlabel("Periodo [Dias]")
plt.ylabel("Magnitud")
# Out:
# Text(0, 0.5, 'Magnitud')

# %%
promedio=(df["magMax"]+df["magMin"])/2
plt.scatter(df["P"],promedio, marker=".")
#plt.scatter(df["P"],df["magMin"])
plt.xscale('log')
plt.gca().invert_yaxis()
slope, intercept, r_value, p_value, std_err = linregress(np.log(df["P"]),promedio)
plt.plot(df["P"], slope*np.log(df["P"]) + intercept, color='red', label="P* "+str(slope)+" + "+str(intercept))
plt.legend()
plt.title("Magnitudes Promedio de Estrellas Cefeidas de SMC")
plt.xlabel("Periodo [Dias]")
plt.ylabel("Magnitud")
# Out:
# Text(0, 0.5, 'Magnitud')

# %%
dif=abs(df["magMax"]-df["magMin"])
plt.scatter(df["P"],dif)
#plt.scatter(df["P"],df["magMin"])
plt.xscale('log')
#plt.gca().invert_yaxis()
plt.title(" Diferencia de Magnitudes de Estrellas Cefeidas de SMC")
plt.xlabel("Periodo [Dias]")
plt.ylabel("Diferencia Absoluta entre Magnitud Max-Min")
# Out:
# Text(0, 0.5, 'Diferencia Absoluta entre Magnitud Max-Min')

# %%
mag_abs=-2.81*np.log10(df["P"])-1.43
plt.scatter(df["P"],mag_abs)
plt.xscale('log')
plt.gca().invert_yaxis()
slope, intercept, r_value, p_value, std_err = linregress(np.log(df["P"]),mag_abs)
plt.plot(df["P"], slope*np.log(df["P"]) + intercept, color='red', label="P* "+str(slope)+" + "+str(intercept))
plt.legend()
plt.title("Magnitudes Absoluta Promedio Segun Periodo")
plt.xlabel("Periodo [Dias]")
plt.ylabel("Magnitud Absoluta")
# Out:
# Text(0, 0.5, 'Magnitud Absoluta')

# %%
dist=10**((mag_abs-promedio-5)/-5)
plt.scatter(df["P"],dist)
plt.xscale('log')
plt.plot(df["P"],np.ones_like(df["P"])*dist.mean(),color="r",label="Distancia Promedio: "+str(dist.mean()/1000)+"KPc")
plt.legend()
plt.xlabel("Periodo [Dias]")
plt.ylabel("Distancia [Pc]")
plt.title("Estimado Distancia de SMC")
# Out:
# Text(0.5, 1.0, 'Estimado Distancia de SMC')

# %%
plt.hist(dist)

plt.grid(True)


# Add legend
plt.legend()
plt.xlabel("Distancia [Pc]")
plt.title("Histograma de Distancia de SMC")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 1.0, 'Histograma de Distancia de SMC')

# %%
df=pd.read_csv(r"C:\Users\juang\Documents\Tareas JD\Universidad\Materias\7 Semestre\Astronomia Galactica\Practica 11\M31.csv")
df.shape
# Out:
# (372, 4)

# %%
df=df.sort_values(by="P")

# %%
promedio=(df["magMax"]+df["magMin"])/2
plt.scatter(df["P"],promedio, marker=".")
#plt.scatter(df["P"],df["magMin"])
plt.xscale('log')
plt.gca().invert_yaxis()
slope, intercept, r_value, p_value, std_err = linregress(np.log(df["P"]),promedio)
plt.plot(df["P"], slope*np.log(df["P"]) + intercept, color='red', label="P* "+str(slope)+" + "+str(intercept))
plt.legend()
plt.title("Magnitudes Promedio de Estrellas Cefeidas de Andromeda")
plt.xlabel("Periodo [Dias]")
plt.ylabel("Magnitud")
plt.grid(True)

# %%
mag_abs=-2.81*np.log10(df["P"])-1.43
plt.scatter(df["P"],mag_abs)
plt.xscale('log')
plt.gca().invert_yaxis()
slope, intercept, r_value, p_value, std_err = linregress(np.log(df["P"]),mag_abs)
plt.plot(df["P"], slope*np.log(df["P"]) + intercept, color='red', label="P* "+str(slope)+" + "+str(intercept))
plt.legend()
plt.title("Magnitudes Absoluta Promedio Segun Periodo")
plt.xlabel("Periodo [Dias]")
plt.ylabel("Magnitud Absoluta")
# Out:
# Text(0, 0.5, 'Magnitud Absoluta')

# %%
dist=10**((promedio-mag_abs+5)/5)
plt.scatter(df["P"],dist)
plt.xscale('log')
plt.plot(df["P"],np.ones_like(df["P"])*dist.mean(),color="r",label="Distancia Promedio: "+str(dist.mean()/1000)+" KPc")
plt.legend()
plt.xlabel("Periodo [Dias]")
plt.ylabel("Distancia [Pc]")
plt.title("Estimado Distancia Andromeda")
plt.grid(True)

# %%
plt.hist(dist)
plt.grid(True)
plt.xlabel("Distancia [Pc]")
plt.title("Hisograma de Distancia de Andromeda")
# Out:
# Text(0.5, 1.0, 'Hisograma de Distancia de Andromeda')

# %%
df=pd.read_csv(r"C:\Users\juang\Documents\Tareas JD\Universidad\Materias\7 Semestre\Astronomia Galactica\Practica 11\M33.csv")
df.shape
# Out:
# (111, 4)

# %%
promedio=(df["magMax"]+df["magMin"])/2
plt.scatter(df["P"],promedio, marker=".")
#plt.scatter(df["P"],df["magMin"])
plt.xscale('log')
plt.gca().invert_yaxis()
slope, intercept, r_value, p_value, std_err = linregress(np.log(df["P"]),promedio)
plt.plot(df["P"], slope*np.log(df["P"]) + intercept, color='red', label="P* "+str(slope)+" + "+str(intercept))
plt.legend()
plt.title("Magnitudes Promedio de Estrellas Cefeidas de M33")
plt.xlabel("Periodo [Dias]")
plt.ylabel("Magnitud")
plt.grid(True)

# %%
mag_abs=-2.81*np.log10(df["P"])-1.43
plt.scatter(df["P"],mag_abs)
plt.xscale('log')
plt.gca().invert_yaxis()
slope, intercept, r_value, p_value, std_err = linregress(np.log(df["P"]),mag_abs)
plt.plot(df["P"], slope*np.log(df["P"]) + intercept, color='red', label="P* "+str(slope)+" + "+str(intercept))
plt.legend()
plt.title("Magnitudes Absoluta Promedio Segun Periodo")
plt.xlabel("Periodo [Dias]")
plt.ylabel("Magnitud Absoluta")
# Out:
# Text(0, 0.5, 'Magnitud Absoluta')

# %%
dist=10**((promedio-mag_abs+5)/5)
plt.scatter(df["P"],dist)
plt.xscale('log')
plt.plot(df["P"],np.ones_like(df["P"])*dist.median(),color="r",label="Distancia Promedio: "+str(dist.mean()/1000)+" KPc")
plt.legend()
plt.xlabel("Periodo [Dias]")
plt.ylabel("Distancia [Pc]")
plt.title("Estimado Distancia de M33")
plt.grid(True)

# %%
plt.hist(dist)
plt.grid(True)
plt.title("Histograma de Distancia de M33")
plt.xlabel("Distancia [Pc]")
# Out:
# Text(0.5, 0, 'Distancia [Pc]')
